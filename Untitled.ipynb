# %%
# !python train.py --name_prefix demo --dataname CVLtrH32 --capitalize --display_port 8192
# Out:
# ----------------- Options ---------------
#                    BN_eps: 1e-05
#                      D_B1: 0.0
#                      D_B2: 0.999
#                    D_attn: 64
#                      D_ch: 64
#                   D_depth: 1
#                    D_fp16: False
#                    D_init: N02
#                      D_lr: 0.0002
#         D_mixed_precision: False
#                      D_nl: relu
#                   D_ortho: 0.0
#                   D_param: SN
#                    D_wide: True
#                      G_B1: 0.0
#                      G_B2: 0.999
#                    G_attn: 64
#              G_batch_size: 0
#                      G_ch: 64
#                   G_depth: 1
#                    G_fp16: False
#                    G_init: N02
#                      G_lr: 0.0002
#         G_mixed_precision: False
#                      G_nl: relu
#                   G_ortho: 0.0
#                   G_param: SN
#                  G_shared: False
# ...

# %%
import lmdb

lmdb.open('/mnt/B4204FDF204FA768/convolutional-handwriting-gan/Datasets/CVL/h32/train_new_partition',
            max_readers=1,
            readonly=True,
            lock=False,
            readahead=False,
            meminit=False)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-5-0eabe63ea417> in <module>
#       6             lock=False,
#       7             readahead=False,
# ----> 8             meminit=False)
#
# Error: /mnt/B4204FDF204FA768/convolutional-handwriting-gan/Datasets/CVL/h32/train_new_partition: No such file or directory
